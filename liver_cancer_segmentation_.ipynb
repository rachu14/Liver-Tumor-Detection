# %% [markdown]
# <a href="https://colab.research.google.com/github/rachu14/Liver-Tumor-Detection/blob/main/liver_cancer_segmentation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive. mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/archive.zip
# Out:
# Archive:  /content/gdrive/MyDrive/archive.zip
#   inflating: segmentations/segmentation-0.nii
#   inflating: segmentations/segmentation-1.nii
#   inflating: segmentations/segmentation-10.nii
#   inflating: segmentations/segmentation-100.nii
#   inflating: segmentations/segmentation-101.nii
#   inflating: segmentations/segmentation-102.nii
#   inflating: segmentations/segmentation-103.nii
#   inflating: segmentations/segmentation-104.nii
#   inflating: segmentations/segmentation-105.nii
#   inflating: segmentations/segmentation-106.nii
#   inflating: segmentations/segmentation-107.nii
#   inflating: segmentations/segmentation-108.nii
#   inflating: segmentations/segmentation-109.nii
#   inflating: segmentations/segmentation-11.nii
#   inflating: segmentations/segmentation-110.nii
#   inflating: segmentations/segmentation-111.nii
#   inflating: segmentations/segmentation-112.nii
#   inflating: segmentations/segmentation-113.nii
#   inflating: segmentations/segmentation-114.nii
#   inflating: segmentations/segmentation-115.nii
#   inflating: segmentations/segmentation-116.nii
#   inflating: segmentations/segmentation-117.nii
#   inflating: segmentations/segmentation-118.nii
#   inflating: segmentations/segmentation-119.nii
#   inflating: segmentations/segmentation-12.nii
#   inflating: segmentations/segmentation-120.nii
#   inflating: segmentations/segmentation-121.nii
#   inflating: segmentations/segmentation-122.nii
#   inflating: segmentations/segmentation-123.nii
#   inflating: segmentations/segmentation-124.nii
#   inflating: segmentations/segmentation-125.nii
#   inflating: segmentations/segmentation-126.nii
#   inflating: segmentations/segmentation-127.nii
#   inflating: segmentations/segmentation-128.nii
#   inflating: segmentations/segmentation-129.nii
#   inflating: segmentations/segmentation-13.nii
#   inflating: segmentations/segmentation-130.nii
#   inflating: segmentations/segmentation-14.nii
#   inflating: segmentations/segmentation-15.nii
#   inflating: segmentations/segmentation-16.nii
#   inflating: segmentations/segmentation-17.nii
#   inflating: segmentations/segmentation-18.nii
#   inflating: segmentations/segmentation-19.nii
#   inflating: segmentations/segmentation-2.nii
#   inflating: segmentations/segmentation-20.nii
#   inflating: segmentations/segmentation-21.nii
#   inflating: segmentations/segmentation-22.nii
#   inflating: segmentations/segmentation-23.nii
#   inflating: segmentations/segmentation-24.nii
#   inflating: segmentations/segmentation-25.nii
#   inflating: segmentations/segmentation-26.nii
#   inflating: segmentations/segmentation-27.nii
#   inflating: segmentations/segmentation-28.nii
#   inflating: segmentations/segmentation-29.nii
#   inflating: segmentations/segmentation-3.nii
#   inflating: segmentations/segmentation-30.nii
#   inflating: segmentations/segmentation-31.nii
#   inflating: segmentations/segmentation-32.nii
#   inflating: segmentations/segmentation-33.nii
#   inflating: segmentations/segmentation-34.nii
#   inflating: segmentations/segmentation-35.nii
#   inflating: segmentations/segmentation-36.nii
#   inflating: segmentations/segmentation-37.nii
#   inflating: segmentations/segmentation-38.nii
#   inflating: segmentations/segmentation-39.nii
#   inflating: segmentations/segmentation-4.nii
#   inflating: segmentations/segmentation-40.nii
#   inflating: segmentations/segmentation-41.nii
#   inflating: segmentations/segmentation-42.nii
#   inflating: segmentations/segmentation-43.nii
#   inflating: segmentations/segmentation-44.nii
#   inflating: segmentations/segmentation-45.nii
#   inflating: segmentations/segmentation-46.nii
#   inflating: segmentations/segmentation-47.nii
#   inflating: segmentations/segmentation-48.nii
#   inflating: segmentations/segmentation-49.nii
#   inflating: segmentations/segmentation-5.nii
#   inflating: segmentations/segmentation-50.nii
#   inflating: segmentations/segmentation-51.nii
#   inflating: segmentations/segmentation-52.nii
#   inflating: segmentations/segmentation-53.nii
#   inflating: segmentations/segmentation-54.nii
#   inflating: segmentations/segmentation-55.nii
#   inflating: segmentations/segmentation-56.nii
#   inflating: segmentations/segmentation-57.nii
#   inflating: segmentations/segmentation-58.nii
#   inflating: segmentations/segmentation-59.nii
#   inflating: segmentations/segmentation-6.nii
#   inflating: segmentations/segmentation-60.nii
#   inflating: segmentations/segmentation-61.nii
#   inflating: segmentations/segmentation-62.nii
#   inflating: segmentations/segmentation-63.nii
#   inflating: segmentations/segmentation-64.nii
#   inflating: segmentations/segmentation-65.nii
#   inflating: segmentations/segmentation-66.nii
#   inflating: segmentations/segmentation-67.nii
#   inflating: segmentations/segmentation-68.nii
#   inflating: segmentations/segmentation-69.nii
#   inflating: segmentations/segmentation-7.nii
#   inflating: segmentations/segmentation-70.nii
#   inflating: segmentations/segmentation-71.nii
#   inflating: segmentations/segmentation-72.nii
#   inflating: segmentations/segmentation-73.nii
#   inflating: segmentations/segmentation-74.nii
#   inflating: segmentations/segmentation-75.nii
#   inflating: segmentations/segmentation-76.nii
#   inflating: segmentations/segmentation-77.nii
#   inflating: segmentations/segmentation-78.nii
#   inflating: segmentations/segmentation-79.nii
#   inflating: segmentations/segmentation-8.nii
#   inflating: segmentations/segmentation-80.nii
#   inflating: segmentations/segmentation-81.nii
#   inflating: segmentations/segmentation-82.nii
#   inflating: segmentations/segmentation-83.nii
#   inflating: segmentations/segmentation-84.nii
#   inflating: segmentations/segmentation-85.nii
#   inflating: segmentations/segmentation-86.nii
#   inflating: segmentations/segmentation-87.nii
#   inflating: segmentations/segmentation-88.nii
#   inflating: segmentations/segmentation-89.nii
#   inflating: segmentations/segmentation-9.nii
#   inflating: segmentations/segmentation-90.nii
#   inflating: segmentations/segmentation-91.nii
#   inflating: segmentations/segmentation-92.nii
#   inflating: segmentations/segmentation-93.nii
#   inflating: segmentations/segmentation-94.nii
#   inflating: segmentations/segmentation-95.nii
#   inflating: segmentations/segmentation-96.nii
#   inflating: segmentations/segmentation-97.nii
#   inflating: segmentations/segmentation-98.nii
#   inflating: segmentations/segmentation-99.nii
#   inflating: volume_pt1/volume-0.nii
#   inflating: volume_pt1/volume-1.nii
#   inflating: volume_pt1/volume-10.nii
#   inflating: volume_pt1/volume-2.nii
#   inflating: volume_pt1/volume-3.nii
#   inflating: volume_pt1/volume-4.nii
#   inflating: volume_pt1/volume-5.nii
#   inflating: volume_pt1/volume-6.nii
#   inflating: volume_pt1/volume-7.nii
#   inflating: volume_pt1/volume-8.nii
#   inflating: volume_pt1/volume-9.nii
#   inflating: volume_pt2/volume-11.nii
#   inflating: volume_pt2/volume-12.nii
#   inflating: volume_pt2/volume-13.nii
#   inflating: volume_pt2/volume-14.nii
#   inflating: volume_pt2/volume-15.nii
#   inflating: volume_pt2/volume-16.nii
#   inflating: volume_pt2/volume-17.nii
#   inflating: volume_pt2/volume-18.nii
#   inflating: volume_pt2/volume-19.nii
#   inflating: volume_pt2/volume-20.nii
#   inflating: volume_pt3/volume-21.nii
#   inflating: volume_pt3/volume-22.nii
#   inflating: volume_pt3/volume-23.nii
#   inflating: volume_pt3/volume-24.nii
#   inflating: volume_pt3/volume-25.nii
#   inflating: volume_pt3/volume-26.nii
#   inflating: volume_pt3/volume-27.nii
#   inflating: volume_pt3/volume-28.nii
#   inflating: volume_pt3/volume-29.nii
#   inflating: volume_pt3/volume-30.nii
#   inflating: volume_pt4/volume-31.nii
#   inflating: volume_pt4/volume-32.nii
#   inflating: volume_pt4/volume-33.nii
#   inflating: volume_pt4/volume-34.nii
#   inflating: volume_pt4/volume-35.nii
#   inflating: volume_pt4/volume-36.nii
#   inflating: volume_pt4/volume-37.nii
#   inflating: volume_pt4/volume-38.nii
#   inflating: volume_pt4/volume-39.nii
#   inflating: volume_pt4/volume-40.nii
#   inflating: volume_pt5/volume-41.nii
#   inflating: volume_pt5/volume-42.nii
#   inflating: volume_pt5/volume-43.nii
#   inflating: volume_pt5/volume-44.nii
#   inflating: volume_pt5/volume-45.nii
#   inflating: volume_pt5/volume-46.nii
#   inflating: volume_pt5/volume-47.nii
#   inflating: volume_pt5/volume-48.nii
#   inflating: volume_pt5/volume-49.nii
#   inflating: volume_pt5/volume-50.nii

# %%
# !pip install --upgrade kornia > /dev/null
# !pip install --upgrade fastai > /dev/null

# %%
import os
import glob
import cv2
import imageio

import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from ipywidgets import *
from PIL import Image
from matplotlib.pyplot import figure

from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *

# %%
# Create a meta file for nii files processing

file_list = []
for dirname, _, filenames in os.walk('/content/liver-tumor-segment-part1'):
    for filename in filenames:
        file_list.append((dirname, filename))

for dirname, _, filenames in os.walk('/content/liver-tumor-segment-part2'):
    for filename in filenames:
        file_list.append((dirname, filename))

df_files = pd.DataFrame(file_list, columns =['dirname', 'filename'])
df_files.sort_values(by=['filename'], ascending=True)
# Out:
#                                               dirname              filename
# 7    /content/liver-tumor-segment-part1/segmentations    segmentation-0.nii
# 4    /content/liver-tumor-segment-part1/segmentations    segmentation-1.nii
# 12   /content/liver-tumor-segment-part1/segmentations   segmentation-10.nii
# 63   /content/liver-tumor-segment-part1/segmentations  segmentation-100.nii
# 14   /content/liver-tumor-segment-part1/segmentations  segmentation-101.nii
# ..                                                ...                   ...
# 134     /content/liver-tumor-segment-part2/volume_pt5         volume-50.nii
# 142     /content/liver-tumor-segment-part2/volume_pt1          volume-6.nii
# 141     /content/liver-tumor-segment-part2/volume_pt1          volume-7.nii
# 147     /content/liver-tumor-segment-part2/volume_pt1          volume-8.nii
# 145     /content/liver-tumor-segment-part2/volume_pt1          volume-9.nii
#
# [182 rows x 2 columns]

# %%
# Map CT scan and label

df_files["mask_dirname"]  = ""
df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"

    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = "/content/liver-tumor-segment-part1/segmentations"

# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True)

df_files
# Out:
#                                           dirname       filename  \
# 0   /content/liver-tumor-segment-part2/volume_pt1   volume-0.nii
# 1   /content/liver-tumor-segment-part2/volume_pt1   volume-1.nii
# 2   /content/liver-tumor-segment-part2/volume_pt1  volume-10.nii
# 3   /content/liver-tumor-segment-part2/volume_pt2  volume-11.nii
# 4   /content/liver-tumor-segment-part2/volume_pt2  volume-12.nii
# 5   /content/liver-tumor-segment-part2/volume_pt2  volume-13.nii
# 6   /content/liver-tumor-segment-part2/volume_pt2  volume-14.nii
# 7   /content/liver-tumor-segment-part2/volume_pt2  volume-15.nii
# 8   /content/liver-tumor-segment-part2/volume_pt2  volume-16.nii
# 9   /content/liver-tumor-segment-part2/volume_pt2  volume-17.nii
# 10  /content/liver-tumor-segment-part2/volume_pt2  volume-18.nii
# 11  /content/liver-tumor-segment-part2/volume_pt2  volume-19.nii
# 12  /content/liver-tumor-segment-part2/volume_pt1   volume-2.nii
# 13  /content/liver-tumor-segment-part2/volume_pt2  volume-20.nii
# 14  /content/liver-tumor-segment-part2/volume_pt3  volume-21.nii
# 15  /content/liver-tumor-segment-part2/volume_pt3  volume-22.nii
# 16  /content/liver-tumor-segment-part2/volume_pt3  volume-23.nii
# 17  /content/liver-tumor-segment-part2/volume_pt3  volume-24.nii
# 18  /content/liver-tumor-segment-part2/volume_pt3  volume-25.nii
# 19  /content/liver-tumor-segment-part2/volume_pt3  volume-26.nii
# 20  /content/liver-tumor-segment-part2/volume_pt3  volume-27.nii
# 21  /content/liver-tumor-segment-part2/volume_pt3  volume-28.nii
# 22  /content/liver-tumor-segment-part2/volume_pt3  volume-29.nii
# 23  /content/liver-tumor-segment-part2/volume_pt1   volume-3.nii
# 24  /content/liver-tumor-segment-part2/volume_pt3  volume-30.nii
# 25  /content/liver-tumor-segment-part2/volume_pt4  volume-31.nii
# 26  /content/liver-tumor-segment-part2/volume_pt4  volume-32.nii
# 27  /content/liver-tumor-segment-part2/volume_pt4  volume-33.nii
# 28  /content/liver-tumor-segment-part2/volume_pt4  volume-34.nii
# 29  /content/liver-tumor-segment-part2/volume_pt4  volume-35.nii
# 30  /content/liver-tumor-segment-part2/volume_pt4  volume-36.nii
# 31  /content/liver-tumor-segment-part2/volume_pt4  volume-37.nii
# 32  /content/liver-tumor-segment-part2/volume_pt4  volume-38.nii
# 33  /content/liver-tumor-segment-part2/volume_pt4  volume-39.nii
# 34  /content/liver-tumor-segment-part2/volume_pt1   volume-4.nii
# 35  /content/liver-tumor-segment-part2/volume_pt4  volume-40.nii
# 36  /content/liver-tumor-segment-part2/volume_pt5  volume-41.nii
# 37  /content/liver-tumor-segment-part2/volume_pt5  volume-42.nii
# 38  /content/liver-tumor-segment-part2/volume_pt5  volume-43.nii
# 39  /content/liver-tumor-segment-part2/volume_pt5  volume-44.nii
# 40  /content/liver-tumor-segment-part2/volume_pt5  volume-45.nii
# 41  /content/liver-tumor-segment-part2/volume_pt5  volume-46.nii
# 42  /content/liver-tumor-segment-part2/volume_pt5  volume-47.nii
# 43  /content/liver-tumor-segment-part2/volume_pt5  volume-48.nii
# 44  /content/liver-tumor-segment-part2/volume_pt5  volume-49.nii
# 45  /content/liver-tumor-segment-part2/volume_pt1   volume-5.nii
# 46  /content/liver-tumor-segment-part2/volume_pt5  volume-50.nii
# 47  /content/liver-tumor-segment-part2/volume_pt1   volume-6.nii
# 48  /content/liver-tumor-segment-part2/volume_pt1   volume-7.nii
# 49  /content/liver-tumor-segment-part2/volume_pt1   volume-8.nii
# 50  /content/liver-tumor-segment-part2/volume_pt1   volume-9.nii
#
#                                         mask_dirname        mask_filename
# 0   /content/liver-tumor-segment-part1/segmentations   segmentation-0.nii
# 1   /content/liver-tumor-segment-part1/segmentations   segmentation-1.nii
# 2   /content/liver-tumor-segment-part1/segmentations  segmentation-10.nii
# 3   /content/liver-tumor-segment-part1/segmentations  segmentation-11.nii
# 4   /content/liver-tumor-segment-part1/segmentations  segmentation-12.nii
# 5   /content/liver-tumor-segment-part1/segmentations  segmentation-13.nii
# 6   /content/liver-tumor-segment-part1/segmentations  segmentation-14.nii
# 7   /content/liver-tumor-segment-part1/segmentations  segmentation-15.nii
# 8   /content/liver-tumor-segment-part1/segmentations  segmentation-16.nii
# 9   /content/liver-tumor-segment-part1/segmentations  segmentation-17.nii
# 10  /content/liver-tumor-segment-part1/segmentations  segmentation-18.nii
# 11  /content/liver-tumor-segment-part1/segmentations  segmentation-19.nii
# 12  /content/liver-tumor-segment-part1/segmentations   segmentation-2.nii
# 13  /content/liver-tumor-segment-part1/segmentations  segmentation-20.nii
# 14  /content/liver-tumor-segment-part1/segmentations  segmentation-21.nii
# 15  /content/liver-tumor-segment-part1/segmentations  segmentation-22.nii
# 16  /content/liver-tumor-segment-part1/segmentations  segmentation-23.nii
# 17  /content/liver-tumor-segment-part1/segmentations  segmentation-24.nii
# 18  /content/liver-tumor-segment-part1/segmentations  segmentation-25.nii
# 19  /content/liver-tumor-segment-part1/segmentations  segmentation-26.nii
# 20  /content/liver-tumor-segment-part1/segmentations  segmentation-27.nii
# 21  /content/liver-tumor-segment-part1/segmentations  segmentation-28.nii
# 22  /content/liver-tumor-segment-part1/segmentations  segmentation-29.nii
# 23  /content/liver-tumor-segment-part1/segmentations   segmentation-3.nii
# 24  /content/liver-tumor-segment-part1/segmentations  segmentation-30.nii
# 25  /content/liver-tumor-segment-part1/segmentations  segmentation-31.nii
# 26  /content/liver-tumor-segment-part1/segmentations  segmentation-32.nii
# 27  /content/liver-tumor-segment-part1/segmentations  segmentation-33.nii
# 28  /content/liver-tumor-segment-part1/segmentations  segmentation-34.nii
# 29  /content/liver-tumor-segment-part1/segmentations  segmentation-35.nii
# 30  /content/liver-tumor-segment-part1/segmentations  segmentation-36.nii
# 31  /content/liver-tumor-segment-part1/segmentations  segmentation-37.nii
# 32  /content/liver-tumor-segment-part1/segmentations  segmentation-38.nii
# 33  /content/liver-tumor-segment-part1/segmentations  segmentation-39.nii
# 34  /content/liver-tumor-segment-part1/segmentations   segmentation-4.nii
# 35  /content/liver-tumor-segment-part1/segmentations  segmentation-40.nii
# 36  /content/liver-tumor-segment-part1/segmentations  segmentation-41.nii
# 37  /content/liver-tumor-segment-part1/segmentations  segmentation-42.nii
# 38  /content/liver-tumor-segment-part1/segmentations  segmentation-43.nii
# 39  /content/liver-tumor-segment-part1/segmentations  segmentation-44.nii
# 40  /content/liver-tumor-segment-part1/segmentations  segmentation-45.nii
# 41  /content/liver-tumor-segment-part1/segmentations  segmentation-46.nii
# 42  /content/liver-tumor-segment-part1/segmentations  segmentation-47.nii
# 43  /content/liver-tumor-segment-part1/segmentations  segmentation-48.nii
# 44  /content/liver-tumor-segment-part1/segmentations  segmentation-49.nii
# 45  /content/liver-tumor-segment-part1/segmentations   segmentation-5.nii
# 46  /content/liver-tumor-segment-part1/segmentations  segmentation-50.nii
# 47  /content/liver-tumor-segment-part1/segmentations   segmentation-6.nii
# 48  /content/liver-tumor-segment-part1/segmentations   segmentation-7.nii
# 49  /content/liver-tumor-segment-part1/segmentations   segmentation-8.nii
# 50  /content/liver-tumor-segment-part1/segmentations   segmentation-9.nii

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample

sample = 0
sample_ct = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])

print(f'CT Shape:   {sample_ct.shape}\nMask Shape: {sample_mask.shape}')
# Out:
# CT Shape:   (512, 512, 75)
# Mask Shape: (512, 512, 75)

# %%
print(np.amin(sample_ct), np.amax(sample_ct))
print(np.amin(sample_mask), np.amax(sample_mask))
# Out:
# -3024.0 1410.0
# 0.0 2.0

# %%
dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

figure(figsize=(8, 6), dpi=100)

plt.imshow(tensor(sample_ct[..., 55].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
print(np.amin(sample_ct), np.amax(sample_ct))
print(np.amin(sample_mask), np.amax(sample_mask))
# Out:
# -3024.0 1410.0
# 0.0 2.0

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):
    '''
    Plots and a slice with all available annotations
    '''
    fig = plt.figure(figsize=(20,16), dpi=100)

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')
    plt.axis('off')

    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')
    plt.axis('off')

    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')
    plt.axis('off')

    plt.show()

# %%
sample = 55

sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[..., sample],
             sample_mask[..., sample]])

# %%
# Check the mask values
mask = Image.fromarray(sample_mask[...,sample].astype('uint8'), mode="L")
unique, counts = np.unique(mask, return_counts=True)
print(np.array((unique, counts)).T)
# Out:
# [[     0 244111]
#  [     1  18033]]

# %%
# Preprocessing functions
# Source https://docs.fast.ai/medical.imaging

class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

@patch
def freqhist_bins(self:Tensor, n_bins=100):
    "A function to split the range of pixel values into groups, such that each group has around the same number of pixels"
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()

@patch
def hist_scaled(self:Tensor, brks=None):
    "Scales a tensor using `freqhist_bins` to values between 0 and 1"
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)


@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))

@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=120):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs = subplots(1,1)

sample_slice.save_jpg('test.jpg', [dicom_windows.liver, dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0], figsize=(8, 6))
# Out:
# <Axes: >

# %%
# Make custom JPG files for resnet training
# Total number of 131 nii files contains 67072 slices

GENERATE_JPG_FILES = True

if (GENERATE_JPG_FILES) :

    path = Path(".")

    os.makedirs('train_images',exist_ok=True)
    os.makedirs('train_masks',exist_ok=True)

    for ii in tqdm(range(0,len(df_files),3)): # take 1/3 nii files for training
        curr_ct        = read_nii(df_files.loc[ii,'dirname']+"/"+df_files.loc[ii,'filename'])
        curr_mask      = read_nii(df_files.loc[ii,'mask_dirname']+"/"+df_files.loc[ii,'mask_filename'])
        curr_file_name = str(df_files.loc[ii,'filename']).split('.')[0]
        curr_dim       = curr_ct.shape[2] # 512, 512, curr_dim

        for curr_slice in range(0,curr_dim,2): # export every 2nd slice for training
            data = tensor(curr_ct[...,curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[...,curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver,dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")
else:
    path = Path("../input/liver-segmentation-with-fastai-v2")# read jpg from saved kernel output
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %% [markdown]
# **MODEL TRAINING**

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 128

codes = np.array(["background","liver","tumor"])

def get_x(fname:Path): return fname
def label_func(x): return path/'train_masks'/f'{x.stem}_mask.png'

tfms = [IntToFloatTensor(),Normalize()]

db = DataBlock(blocks=(ImageBlock(),MaskBlock(codes)),  #codes = {"Backround": 0,"Liver": 1,"Tumor": 2}
               batch_tfms=tfms,
               splitter=RandomSplitter(),
               item_tfms=[Resize(IMAGE_SIZE)],
               get_items=get_image_files,
               get_y=label_func)

ds = db.datasets(source=path/'train_images')

# %%
idx = 20
imgs = [ds[idx][0],ds[idx][1]]
fig, axs = plt.subplots(1, 2)

for i,ax in enumerate(axs.flatten()):
    ax.axis('off')
    ax.imshow(imgs[i])

# %%
unique, counts = np.unique(array(ds[idx][1]), return_counts=True)

print( np.array((unique, counts)).T)
# Out:
# [[     0 250436]
#  [     1  11708]]

# %%
dls = db.dataloaders(path/'train_images', bs = BATCH_SIZE) #, num_workers=0
dls.show_batch()

# %%
def foreground_acc(inp, targ, bkg_idx=0, axis=1):  # exclude a background from metric
    "Computes non-background accuracy for multiclass segmentation"
    targ = targ.squeeze(1)
    mask = targ != bkg_idx
    return (inp.argmax(dim=axis)[mask]==targ[mask]).float().mean()

def cust_foreground_acc(inp, targ):  # # include a background into the metric
    return foreground_acc(inp=inp, targ=targ, bkg_idx=3, axis=1) # 3 is a dummy value to include the background which is 0

# %%
learn = unet_learner(dls,
                     resnet50,
                     loss_func=CrossEntropyLossFlat(axis=1),
                     metrics=[foreground_acc, cust_foreground_acc])
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 325MB/s]

# %%
learn.fine_tune(5, wd=0.1, cbs=SaveModelCallback() )
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.580057</td>
#       <td>0.038559</td>
#       <td>0.490194</td>
#       <td>0.986285</td>
#       <td>02:56</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.038558684289455414.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013426</td>
#       <td>0.010430</td>
#       <td>0.920893</td>
#       <td>0.996540</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.009008</td>
#       <td>0.008054</td>
#       <td>0.928409</td>
#       <td>0.997011</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006223</td>
#       <td>0.005251</td>
#       <td>0.953390</td>
#       <td>0.998068</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.004686</td>
#       <td>0.004429</td>
#       <td>0.954127</td>
#       <td>0.998299</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003962</td>
#       <td>0.004202</td>
#       <td>0.961592</td>
#       <td>0.998393</td>
#       <td>02:51</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.010430436581373215.
# Better model found at epoch 1 with valid_loss value: 0.008053849451243877.
# Better model found at epoch 2 with valid_loss value: 0.005250780843198299.
# Better model found at epoch 3 with valid_loss value: 0.004428694024682045.
# Better model found at epoch 4 with valid_loss value: 0.004201875999569893.

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# Save the model
learn.export(path/f'Liver_segmentation')

# %% [markdown]
# **TESTING MODEL**

# %%
# Load saved model
if (GENERATE_JPG_FILES) :

    tfms = [Resize(IMAGE_SIZE), IntToFloatTensor(),Normalize()]
    learn0 = load_learner(path/f'Liver_segmentation',cpu=False )
    learn0.dls.transform = tfms

# %%
def nii_tfm(fn,wins):

    test_nii  = read_nii(fn)
    curr_dim  = test_nii.shape[2] # 512, 512, curr_dim
    slices = []

    for curr_slice in range(curr_dim):
        data = tensor(test_nii[...,curr_slice].astype(np.float32))
        data = (data.to_nchan(wins)*255).byte()
        slices.append(TensorImage(data))

    return slices

# %%
tst = 20

test_nii   = read_nii(df_files.loc[tst,'dirname']+"/"+df_files.loc[tst,'filename'])
test_mask  = read_nii(df_files.loc[tst,'mask_dirname']+"/"+df_files.loc[tst,'mask_filename'])
print(test_nii.shape)

test_slice_idx = 500

sample_slice = tensor(test_nii[...,test_slice_idx].astype(np.float32))

plot_sample([test_nii[...,test_slice_idx], test_mask[...,test_slice_idx]])
# Out:
# (512, 512, 861)
